# %% [markdown]
# **Cladocopium from Acropora cf tenuis samples in the central Philippines - PCA, etc**
#
# Inputs:\
# Eigenvectors and eigenvalues created with Plink2 PCA\
# Lists of sample names belonging to differing cryptic Acropora taxa\
# Cluster evaluation with DFA\
# Created by Jaelyn Bos, May 2025

# %%
#Make sure R can find packages installed through Conda
.libPaths('/hb/home/jbos/.conda/envs/vcfR')
.libPaths("/hb/home/jbos/.conda/envs/vcfR/lib/R/library")

# %%
#Load packages
library(tidyverse)
library(vcfR)
library(hierfstat)
library(adegenet)
library(poppr)
library(cowplot)
library(ggh4x)
# Out:
# Loading required package: ade4
#
#
#    /// adegenet 2.1.11 is loaded ////////////
#
#    > overview: '?adegenet'
#    > tutorials/doc/questions: 'adegenetWeb()'
#    > bug reports/feature requests: adegenetIssues()
#
#
#
#
# Attaching package: ‘adegenet’
#
#
# The following objects are masked from ‘package:hierfstat’:
#
#     Hs, read.fstat
#
#
# Registered S3 method overwritten by 'pegas':
#   method      from
#   print.amova ade4
#
# This is poppr version 2.9.6. To get started, type package?poppr
# OMP parallel support: available
#
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp

# %%
#Import Cladocopium SNP data in vcf form and convert to genind
vcf<-read.vcfR("vcfs/pruned_snps_cladocopium.vcf")
gi <- vcfR2genind(vcf)
# Out:
# Scanning file to determine attributes.
# File attributes:
#   meta lines: 699
#   header_line: 700
#   variant count: 873
#   column count: 319
# Meta line 699 read in.
# All meta lines processed.
# gt matrix initialized.
# Character matrix gt created.
#   Character matrix gt rows: 873
#   Character matrix gt cols: 319
#   skip: 0
#   nrows: 873
#   row_num: 0
# Processed variant: 873
# All variants processed

# %%
#Use DFA to compare different numbers of genetic clusters by BIC
set.seed(42)
grp_clad<-find.clusters(gi,max.n.clust=16,n.pca=500)
grp_clad$Kstat
# Out:
# Choose the number of clusters (>=2):
#      K=1      K=2      K=3      K=4      K=5      K=6      K=7      K=8
# 1520.312 1520.733 1521.719 1524.330 1526.990 1530.159 1533.506 1536.868
#      K=9     K=10     K=11     K=12     K=13     K=14     K=15     K=16
# 1540.549 1544.362 1548.167 1552.030 1556.016 1559.955 1563.788 1567.787
# Plot with title “Value of BIC
# versus number of clusters”

# %%
#Read in ADMIXTURE out files, plus create a vector of individual names
ind_tab<-read.table('other_data/admix_cladocopium.fam')
ind_names<-paste(ind_tab[,1],'_',ind_tab[,2],sep="")
admix_tab<-read.table('other_data/admix_cladocopium.3.Q')
colnames(admix_tab)<-c('grp1','grp2','grp3')
admix_tab<-cbind(ind_names,admix_tab)

# %%
#Import names of individuals samples assigned to each Acropora cryptic taxon
taxa1<-read.table('other_data/taxa1_dfa.txt',header=FALSE)$V1
taxa2<-read.table('other_data/taxa2_dfa.txt',header=FALSE)$V1
taxa3<-read.table('other_data/taxa3_dfa.txt',header=FALSE)$V1
taxa4<-read.table('other_data/taxa4_dfa.txt',header=FALSE)$V1

# %%
#Add Acropora taxa variable 
admix_tab$Acropora_taxa<-0
admix_tab$Acropora_taxa[admix_tab$ind_names %in% taxa1] <-1
admix_tab$Acropora_taxa[admix_tab$ind_names %in% taxa2] <-2
admix_tab$Acropora_taxa[admix_tab$ind_names %in% taxa3] <-3
admix_tab$Acropora_taxa[admix_tab$ind_names %in% taxa4] <-4
table(admix_tab$Acropora_taxa)
# Out:
#   0   1   2   3   4
#  24 113  71  56  46

# %%
#Sort table by Acropora taxa variable
admix_tab<-admix_tab[order(admix_tab$Acropora_taxa),]

# %%
#Move data to long format for graphing because ggplot secretly wants to be Microsoft Excel
admix_long<-pivot_longer(admix_tab,cols=c('grp1','grp2','grp3'),names_to='group')

# %%
#Import eigenvectors and eigenvalues previously created with Plink2
eigenval <- read.table("other_data/pca_pruned_cladocopium.eigenval", header = FALSE, sep = " ")
eigenvec <- read.table("other_data/pca_pruned_cladocopium.eigenvec", header = FALSE, sep = "\t")
colnames(eigenvec)<-c('Sample_ID','PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10')

# %%
#Calculate the % of variation represented by each principal component
varPC1 <- (eigenval[1,1] / sum(eigenval$V1))*100
varPC2 <- (eigenval[2,1] / sum(eigenval$V1))*100
varPC3 <- (eigenval[3,1] / sum(eigenval$V1))*100

varPC1
varPC2
varPC3
# Out:
# [1] 19.03741
# [1] 17.14229
# [1] 9.632512

# %%
#Add Acropora taxon variable to eigenvector dataset
eigenvec$Taxon<-'Unassigned'
eigenvec$Taxon[eigenvec$Sample_ID %in% taxa1]<-"Taxon1"
eigenvec$Taxon[eigenvec$Sample_ID %in% taxa2]<-"Taxon2"
eigenvec$Taxon[eigenvec$Sample_ID %in% taxa3]<-"Taxon3"
eigenvec$Taxon[eigenvec$Sample_ID %in% taxa4]<-"Taxon4"

# %%
#Assign a color to each Acropora taxon
taxa_colors <- c("Taxon1" = "#440154FF","Taxon2" = "#31688EFF","Taxon3" = "#35B779FF","Taxon4" = "#FDE725FF",'Unassigned' = "#000000")

# %%
#Read in site locations
locs<-read.csv('metadat/all_Atenuis_sites.csv')
colnames(locs)<-c('lon','lat','site')

# %%
#Create ADMIXTURE table sorted by latitude
admix_long$ind_names<-as.character(admix_long$ind_names) 
admix_long$site<-unlist(lapply(strsplit(admix_long$ind_names,"_"), head, 1))
admix_lat<-left_join(admix_long,locs)
admix_lat<-admix_lat[order(admix_lat$lat), ]
admix_lat$ind_names <- factor(admix_lat$ind_names, levels = unique(admix_lat$ind_names))
# Out:
# Joining with `by = join_by(site)`

# %%
#Sort ADMIXTURE dataframe by main ancestry group 
admix_tab<-admix_tab[order(admix_tab$Acropora_taxa),]
#Create long form dataframe for plotting
admix_long<-pivot_longer(admix_tab,cols=c('grp1','grp2','grp3'),names_to='group')
admix_long$ind_names<-factor(admix_long$ind_names, levels = unique(admix_long$ind_names))

# %%
#Make combined PCA and ADMIXTURE plot
p1 <- ggplot(eigenvec, aes(x=PC1, y=PC2, color=Taxon)) +
  geom_point(shape=19, size=5, alpha=0.5) +
  theme_classic() +
  scale_color_manual(name='Acropora \ntaxon', values = taxa_colors) +
  theme(
    plot.title = element_text(size = 24),
    axis.text.x = element_text(size = 16),
    axis.text.y = element_text(size = 16),
    legend.text = element_text(size = 16),
    legend.title = element_text(size = 16),
    axis.title.x = element_text(size = 20),
    axis.title.y = element_text(size = 20))+
  labs(color = "Taxon", x = "PC1:19%", y = "PC2:17%")

adplot <- ggplot(admix_long, aes(x = ind_names, y = value, fill = group)) +
  geom_col(position = position_fill()) +
  facet_grid(. ~ Acropora_taxa, scales = "free_x", space = "free_x") +
  ylab("Ancestry Fraction") +
  labs(fill = "Cladocopopium \nancestry \ngroup") +
  theme(
    plot.title = element_text(size = 18),
    axis.title.y = element_text(size = 20),
    axis.text.x = element_blank(),
    axis.text.y = element_text(size = 18),
    axis.title.x = element_blank(),
    axis.ticks.x = element_blank(),
    legend.text = element_text(size = 16),
    legend.title = element_text(size = 16),
    strip.text = element_text(size = 16)
  )

# Third panel using admix_lat
adplot2 <- ggplot(admix_lat, aes(x = ind_names, y = value, fill = group)) +
  geom_col(position = position_fill()) +
  ylab("Ancestry Fraction") +
  theme(legend.position = "none")+
  theme(
    plot.title = element_text(size = 18),
    axis.title.y = element_text(size = 20),
    axis.text.x = element_blank(),
    axis.text.y = element_text(size = 18),
    axis.title.x = element_blank(),
    axis.ticks.x = element_blank()
  )

p1_adj <- p1 + theme(plot.margin = margin(5.5, 5.5, 5.5, 20, unit = "pt"))
adplot_adj <- adplot + theme(plot.margin = margin(5.5, 5.5, 5.5, 20, unit = "pt"))
adplot2_adj <- adplot2 + theme(plot.margin = margin(5.5, 5.5, 5.5, 20, unit = "pt"))

combined <- plot_grid(
  p1_adj, adplot_adj, adplot2_adj,
  labels = c("A)", "B)", "C)"),
  label_size = 24,
  ncol = 1,
  align = "v",
  axis = "lr"
)

ggsave("figures/Atenuis_Fig5.pdf", combined, width = 8, height = 10, dpi = 1200, units = "in")

combined
# Out:
# plot without title

# %%
#Check % of individuals with >7/8 of ancestry coming from same group
table(apply(admix_tab[,2:4],MARGIN=1,FUN=max)>=0.875)
210/310

#Check % of individuals with >1/2 of ancestry coming from same group
table(apply(admix_tab[,2:4],MARGIN=1,FUN=max)>=0.5)
307/310
# Out:
# FALSE  TRUE
#   100   210
# [1] 0.6774194
# FALSE  TRUE
#     3   307
# [1] 0.9903226

# %%
#Create 'island' (Cebu vs. Leyte) and 'population' (site) variables by splitting sample names. This will be used for later analysis and plotting. 
eigenvec$Island <- substr(eigenvec$Sample_ID,start=1,stop=3)
eigenvec$Pop <- substr(eigenvec$Sample_ID,start=1,stop=5)

# %%
#Read in metadata for individual samples with calculated distance to shore
metadat<-read.csv('metadat/metadata_shoredist.csv')
metadat_sites<-locs

# %%
colnames(metadat_sites)<-c("LONGITUDE","LATITUDE","Name")
metadat_sites$Pop<-metadat_sites$Name

# %%
colnames(metadat_sites)
colnames(eigenvec)
# Out:
# [1] "LONGITUDE" "LATITUDE"  "Name"      "Pop"
#  [1] "Sample_ID" "PC1"       "PC2"       "PC3"       "PC4"       "PC5"
#  [7] "PC6"       "PC7"       "PC8"       "PC9"       "PC10"      "Taxon"
# [13] "Island"    "Pop"

# %%
#Join metadata and eigenvector data. Note that not all individuals have associated metadata; these individuals are dropped
metadat_merge<-left_join(eigenvec,metadat)
sites_merge<-left_join(eigenvec,metadat_sites)
# Out:
# Joining with `by = join_by(Sample_ID)`
# Joining with `by = join_by(Pop)`

# %%
#Check for singificant linear relationshiph between depth and any of the first four PCs for all Cladocopium
summary(lm(PC1 ~ Depth_ft, data=metadat_merge))
summary(lm(PC2 ~ Depth_ft, data=metadat_merge))
summary(lm(PC3 ~ Depth_ft, data=metadat_merge))
summary(lm(PC4 ~ Depth_ft, data=metadat_merge))
table(metadat_merge$Depth_ft>0)
# Out:
# Call:
# lm(formula = PC1 ~ Depth_ft, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.10568 -0.02691 -0.01368  0.00920  0.39868
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.069041   0.016960  -4.071 9.10e-05 ***
# Depth_ft     0.005728   0.001249   4.588 1.25e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06878 on 105 degrees of freedom
#   (203 observations deleted due to missingness)
# Multiple R-squared:  0.167,	Adjusted R-squared:  0.159
# F-statistic: 21.05 on 1 and 105 DF,  p-value: 1.245e-05
# Call:
# lm(formula = PC2 ~ Depth_ft, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35061 -0.00561  0.00103  0.01166  0.31443
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.026436   0.017140  -1.542   0.1260
# Depth_ft     0.002357   0.001262   1.868   0.0646 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06951 on 105 degrees of freedom
#   (203 observations deleted due to missingness)
# Multiple R-squared:  0.03216,	Adjusted R-squared:  0.02294
# F-statistic: 3.489 on 1 and 105 DF,  p-value: 0.06458
# Call:
# lm(formula = PC3 ~ Depth_ft, data = metadat_merge)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.040106 -0.007600 -0.000407  0.006125  0.059194
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.0006678  0.0037528  -0.178    0.859
# Depth_ft    -0.0004032  0.0002763  -1.459    0.147
#
# Residual standard error: 0.01522 on 105 degrees of freedom
#   (203 observations deleted due to missingness)
# Multiple R-squared:  0.01988,	Adjusted R-squared:  0.01054
# F-statistic:  2.13 on 1 and 105 DF,  p-value: 0.1475
# Call:
# lm(formula = PC4 ~ Depth_ft, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.45929 -0.00614  0.01019  0.02042  0.05897
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.0125023  0.0128875  -0.970    0.334
# Depth_ft     0.0010414  0.0009488   1.098    0.275
#
# Residual standard error: 0.05227 on 105 degrees of freedom
#   (203 observations deleted due to missingness)
# Multiple R-squared:  0.01134,	Adjusted R-squared:  0.001927
# F-statistic: 1.205 on 1 and 105 DF,  p-value: 0.2749
# TRUE
#  107

# %%
#Check for singificant linear relationshiph between distance to shore and any of the first four PCs for all Cladocopium
summary(lm(PC1 ~ SHOREDIST, data=metadat_merge))
summary(lm(PC2 ~ SHOREDIST, data=metadat_merge))
summary(lm(PC3 ~ SHOREDIST, data=metadat_merge))
summary(lm(PC4 ~ SHOREDIST, data=metadat_merge))
# Out:
# Call:
# lm(formula = PC1 ~ SHOREDIST, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.02979 -0.01798 -0.01352 -0.00770  0.46879
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.316e-05  3.496e-03   0.009    0.992
# SHOREDIST   1.231e-07  2.733e-07   0.450    0.653
#
# Residual standard error: 0.05804 on 296 degrees of freedom
#   (12 observations deleted due to missingness)
# Multiple R-squared:  0.0006845,	Adjusted R-squared:  -0.002692
# F-statistic: 0.2028 on 1 and 296 DF,  p-value: 0.6528
# Call:
# lm(formula = PC2 ~ SHOREDIST, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35247 -0.00226  0.00125  0.00683  0.38577
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.355e-03  3.486e-03   0.389    0.698
# SHOREDIST   -4.166e-07  2.726e-07  -1.528    0.127
#
# Residual standard error: 0.05787 on 296 degrees of freedom
#   (12 observations deleted due to missingness)
# Multiple R-squared:  0.007829,	Adjusted R-squared:  0.004478
# F-statistic: 2.336 on 1 and 296 DF,  p-value: 0.1275
# Call:
# lm(formula = PC3 ~ SHOREDIST, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.06714 -0.01413 -0.00578  0.00229  0.82764
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.782e-04  3.495e-03   0.194    0.846
# SHOREDIST   -1.982e-07  2.733e-07  -0.725    0.469
#
# Residual standard error: 0.05802 on 296 degrees of freedom
#   (12 observations deleted due to missingness)
# Multiple R-squared:  0.001775,	Adjusted R-squared:  -0.001598
# F-statistic: 0.5262 on 1 and 296 DF,  p-value: 0.4688
# Call:
# lm(formula = PC4 ~ SHOREDIST, data = metadat_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.65435 -0.00556  0.01171  0.02144  0.05552
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.383e-04  3.490e-03  -0.126    0.900
# SHOREDIST   -2.481e-07  2.728e-07  -0.909    0.364
#
# Residual standard error: 0.05794 on 296 degrees of freedom
#   (12 observations deleted due to missingness)
# Multiple R-squared:  0.002786,	Adjusted R-squared:  -0.0005827
# F-statistic: 0.827 on 1 and 296 DF,  p-value: 0.3639

# %%
#Check for singificant linear relationshiph between latitude and any of the first four PCs for all Cladocopium
summary(lm(PC1 ~ LATITUDE, data=sites_merge))
summary(lm(PC2 ~ LATITUDE, data=sites_merge))
summary(lm(PC3 ~ LATITUDE, data=sites_merge))
summary(lm(PC4 ~ LATITUDE, data=sites_merge))
table(sites_merge$LATITUDE>0)
# Out:
# Call:
# lm(formula = PC1 ~ LATITUDE, data = sites_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.02954 -0.01732 -0.01321 -0.00764  0.46732
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.019337   0.068332   0.283    0.777
# LATITUDE    -0.001862   0.006580  -0.283    0.777
#
# Residual standard error: 0.05697 on 308 degrees of freedom
# Multiple R-squared:  0.0002598,	Adjusted R-squared:  -0.002986
# F-statistic: 0.08004 on 1 and 308 DF,  p-value: 0.7774
# Call:
# lm(formula = PC2 ~ LATITUDE, data = sites_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35051 -0.00714  0.00435  0.01137  0.36786
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.245740   0.066885   3.674 0.000281 ***
# LATITUDE    -0.023709   0.006441  -3.681 0.000274 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05577 on 308 degrees of freedom
# Multiple R-squared:  0.04214,	Adjusted R-squared:  0.03903
# F-statistic: 13.55 on 1 and 308 DF,  p-value: 0.0002742
# Call:
# lm(formula = PC3 ~ LATITUDE, data = sites_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07703 -0.01286 -0.00574  0.00246  0.83080
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.045526   0.068292  -0.667    0.506
# LATITUDE     0.004386   0.006576   0.667    0.505
#
# Residual standard error: 0.05694 on 308 degrees of freedom
# Multiple R-squared:  0.001442,	Adjusted R-squared:  -0.0018
# F-statistic: 0.4448 on 1 and 308 DF,  p-value: 0.5053
# Call:
# lm(formula = PC4 ~ LATITUDE, data = sites_merge)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.65330 -0.00459  0.01154  0.02089  0.05657
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.015398   0.068325   0.225    0.822
# LATITUDE    -0.001574   0.006580  -0.239    0.811
#
# Residual standard error: 0.05697 on 308 degrees of freedom
# Multiple R-squared:  0.0001857,	Adjusted R-squared:  -0.00306
# F-statistic: 0.05721 on 1 and 308 DF,  p-value: 0.8111
# TRUE
#  310
