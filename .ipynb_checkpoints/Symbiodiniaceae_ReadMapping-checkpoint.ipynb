# %% [markdown]
# Mapping reads to Cladocopium, Symbiodinium, and Durusdinium
# Created by Jaelyn Bos 2025

# %%
.libPaths('/hb/home/jbos/.conda/envs/vcfR')
.libPaths("/hb/home/jbos/.conda/envs/vcfR/lib/R/library")
#.libPaths('/hb/software/apps/r/conda3-4.4.1/lib/R/library')
#.libPaths('/hb/home/jbos/R/x86_64-conda-linux-gnu-library/4.4')

# %%
#Load required packages
library(adegenet)
library(hierfstat)
library(tidyverse)
library(vegan)
library(vcfR)
# Out:
# Loading required package: ade4
#
#
#    /// adegenet 2.1.11 is loaded ////////////
#
#    > overview: '?adegenet'
#    > tutorials/doc/questions: 'adegenetWeb()'
#    > bug reports/feature requests: adegenetIssues()
#
#
#
#
# Attaching package: ‘hierfstat’
#
#
# The following objects are masked from ‘package:adegenet’:
#
#     Hs, read.fstat
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   4.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.6-8
#
#
# ...

# %%
#Function to return genus corresponding to the highest number of reads
max_frac <- function(row) {
    x <- names(row[2:4])[which.max(row[2:4])]
    return(x)
}

# %%
#Read in total number of mapped reads calculated with samtools
clad <- read.table('cladocopium_mapped_number.txt')
colnames(clad)<-c('IND','clad_reads')
dur <- read.table('durusdinium_mapped_number.txt')
colnames(dur)<-c('IND','dur_reads')
sym <- read.table('symbiodinium_mapped_number.txt')
colnames(sym)<-c('IND','sym_reads')

# %%
#Combine number of mapped reads for all three symbiont genera
symbionts <-full_join(clad,dur)
symbionts <-full_join(symbionts,sym)
# Out:
# Joining with `by = join_by(IND)`
# Joining with `by = join_by(IND)`

# %%
#Read in mapping stats for Acropora
corals<-read.table('acropora_mapped_number.txt')

# %%
#Rename columns for Acropora mapping stats
colnames(corals)<-c('IND','acropora_reads')

# %%
#Create combined dataset of total # of reads mapped
map_join<-full_join(corals,symbionts)
# Out:
# Joining with `by = join_by(IND)`

# %%
#Check for correlation between number of reads mapped to Cladocopium and number of reads mapped to Acropora. 
#Highly positive. Probably some samples just sequenced better.
plot(map_join$acropora_reads,map_join$clad_reads,xlab="Number reads mapped Acropora",ylab="Number reads mapped Cladocopium",cex.lab=1.4,cex.axis=1.2,xlim=c(0,1000000),ylim=c(0,600000))
text(600000,400000,round(cor(map_join$acropora_reads,map_join$clad_reads),3),cex=2)

summary(lm(clad_reads ~ acropora_reads, data=map_join))
# Out:
# Call:
# lm(formula = clad_reads ~ acropora_reads, data = map_join)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -436036  -21466  -21204   -1407  606347
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.136e+04  2.775e+03   7.695 5.27e-14 ***
# acropora_reads 1.538e-01  4.713e-03  32.633  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 67550 on 650 degrees of freedom
# Multiple R-squared:  0.621,	Adjusted R-squared:  0.6204
# F-statistic:  1065 on 1 and 650 DF,  p-value: < 2.2e-16
# plot without title

# %%
#Median percent of reads mapping to Cladocopium
median(map_join$clad_reads/rowSums(map_join[,c(2,3,4,5)]))
median(map_join$clad_reads)
# Out:
# [1] 0.1647861
# [1] 14424.5

# %%
#Median percent of reads mapping to Durusdinium
median(map_join$dur_reads/rowSums(map_join[,c(2,3,4,5)]))
median(map_join$dur_reads)
# Out:
# [1] 0.01546935
# [1] 1447

# %%
#Median percent of reads mapping to Symbiodinium
median(map_join$sym_reads/rowSums(map_join[,c(2,3,4,5)]))
median(map_join$sym_reads)
# Out:
# [1] 0.02424904
# [1] 2771

# %%
#For each individual, check which genus of symbionts has the most reads mapped. Make a table of individual corals by dominant symbiont genus.
dominant_symbiont<-apply(symbionts, MARGIN=1, FUN=max_frac)
table(dominant_symbiont)
map_join$max_frac<-dominant_symbiont
# Out:
# dominant_symbiont
# clad_reads  dur_reads  sym_reads
#        644          7          1

# %%
#Look at putative Durusdinium dominant individuals 
dur_dat<-symbionts[(dominant_symbiont=="dur_reads"),]
dur_dat$per<-(dur_dat[,3]/rowSums(dur_dat[,2:4])*100)
dur_dat
# Out:
#     IND       clad_reads dur_reads sym_reads per
# 24  CEB02_T04 21502      455033    14599     92.64946
# 52  CEB04_T05    56          64       10     49.23077
# 186 CEB11_T08  2399       28873     2080     86.57052
# 246 CEB16_T04   164         260       18     58.82353
# 282 CEB18_T20   155         194       31     51.05263
# 310 CEB20_T08 25989      172902    11050     82.35742
# 499 LEY02_T02 18651       31833     4662     57.72495

# %%
#Look at putative Symbiodinium dominant individuals 
sym_dat<-symbionts[(dominant_symbiont=="sym_reads"),]
sym_dat$per<-(sym_dat[,4]/rowSums(sym_dat[,2:4])*100)
sym_dat
# Out:
#     IND       clad_reads dur_reads sym_reads per
# 189 CEB11_T11 11498      1127      22467     64.02314

# %%
#Import names of individual corals assigned to each Acropora taxon
dfa_grp1<-read_csv('taxa1_inds_copy.csv',show_col_types = FALSE)
dfa_grp2<-read_csv('taxa2_inds_copy.csv',show_col_types = FALSE)
dfa_grp3<-read_csv('taxa3_inds_copy.csv',show_col_types = FALSE)
dfa_grp4<-read_csv('taxa4_inds_copy.csv',show_col_types = FALSE)
# Out:
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`

# %%
#Add taxon column to dataset
map_join$taxa[map_join$IND %in% c(dfa_grp1[,2]$x)]<-1
map_join$taxa[map_join$IND %in% c(dfa_grp2[,2]$x)]<-2
map_join$taxa[map_join$IND %in% c(dfa_grp3[,2]$x)]<-3
map_join$taxa[map_join$IND %in% c(dfa_grp4[,2]$x)]<-4

# %%
#Create dataset of only those individuals with enough Acropora reads to be assigned to cryptic taxo.
symbionts_filt <- map_join[!is.na(map_join$taxa),]

# %%
#Make percentages datafram
symbiont_per<- as.data.frame(symbionts_filt[,1])
colnames(symbiont_per) <- 'ID'

# %%
#Calculate percent of total reads that mapped to each taxon
symbiont_per$clad_per <- symbionts_filt$clad_reads/rowSums(symbionts_filt[,c(2:5)])
symbiont_per$dur_per <- symbionts_filt$dur_reads/rowSums(symbionts_filt[,c(2:5)])
symbiont_per$sym_per <- symbionts_filt$sym_reads/rowSums(symbionts_filt[,c(2:5)])
symbiont_per$taxa <- symbionts_filt$taxa

# %%
#Make table showing dominant symbiont by Acropora cryptic taxon
table(symbionts_filt$max_frac,symbionts_filt$taxa)
# Out:
#
#                1   2   3   4
#   clad_reads 113  69  57  52
#   dur_reads    2   0   0   1
#   sym_reads    1   0   0   0

# %%
#Kruskal-Wallis tests for association between symbiont read percentages and Acropora taxon
kruskal.test(clad_per ~ taxa, data=symbiont_per)
kruskal.test(dur_per ~ taxa, data=symbiont_per)
kruskal.test(sym_per ~ taxa, data=symbiont_per)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  clad_per by taxa
# Kruskal-Wallis chi-squared = 16.068, df = 3, p-value = 0.001098
# 	Kruskal-Wallis rank sum test
#
# data:  dur_per by taxa
# Kruskal-Wallis chi-squared = 5.7749, df = 3, p-value = 0.1231
# 	Kruskal-Wallis rank sum test
#
# data:  sym_per by taxa
# Kruskal-Wallis chi-squared = 10.671, df = 3, p-value = 0.01364

# %%
#Make long dataframe of symbiont read percentages
colnames(symbiont_per)<-c('IND','Cladocopium','Durusdinium','Symbiodinium','taxon')
symb_long<-pivot_longer(symbiont_per,cols=c('Cladocopium','Durusdinium','Symbiodinium'),names_to='Symbiont_genus',values_to='reads')

# %%
#Make plot
png("symbiont genus boxplot.png", width=10, height=5, units = "in", res = 300)
boxplot(reads ~ Symbiont_genus,data=symb_long,xlab="Symbiont genus",ylab="% of symbiont reads mapped",cex.lab=1.5,cex.axis=1.1,axes=TRUE,frame.plot=FALSE)
dev.off()
# Out:
# pdf
#   2

# %%
#Boxplot, % symbiont reads mapping to Durusdinium by Acropora taxon
boxplot(Durusdinium ~ taxon, data=symbiont_per,xlab="Acropora taxon",ylab="% reads mapping to Durusdinium",cex.lab=1.5,cex.axis=1.1,ylim=c(0,1),axes=TRUE,frame.plot=FALSE)
# Out:
# plot without title

# %%
#Boxplot, % symbiont reads mapping to Symbiodinium by Acropora taxon
boxplot(Symbiodinium ~ taxon, data=symbiont_per,xlab="Acropora taxon",ylab="% reads mapping to Symbiodinium",cex.lab=1.5,cex.axis=1.1,ylim=c(0,1),axes=TRUE,frame.plot=FALSE)
# Out:
# plot without title

# %%
#Kruskal-Wallis test for number of Acropora reads mapped by Acropora taxon
kruskal.test(acropora_reads ~ taxa, data=map_join)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  acropora_reads by taxa
# Kruskal-Wallis chi-squared = 6.0205, df = 3, p-value = 0.1106

# %%
#Import metadata
metadat<-read.csv('metadata_shoredist.csv')
metadat$ID<-metadat$Sample_ID

# %%
#Look at metadata for Durusdinium dominant individuals
metadat[metadat$ID %in% dur_dat$IND,]
# Out:
#     X   Unnamed..0 Sample_ID Time  Day Month Year Depth_ft Unnamed..6
# 7     6   6        CEB16_T04 13:21 22  1     2016 NA       NA
# 199 198 198        CEB20_T08 11:32 12  2     2016 NA       NA
# 243 242 242        CEB18_T20 14:41 14  2     2016 NA       NA
# 267 266 266        CEB02_T04 10:55 28  2     2016 NA       NA
# 297 296 296        CEB04_T05 14:16  1  3     2016 NA       NA
# 411 410 410        CEB11_T08 11:44  7  3     2016  9       NA
# 513 512 512        LEY02_T02 10:54 24  3     2016 13       NA
#     Unnamed..7 ⋯ dt                        lat      lon
# 7              ⋯ 2016-01-22 13:21:00+08:00 10.22330 123.9166
# 199            ⋯ 2016-02-12 11:32:00+08:00       NA       NA
# 243            ⋯ 2016-02-14 14:41:00+08:00 10.18154 123.7430
# 267            ⋯ 2016-02-28 10:55:00+08:00 11.26646 124.0708
# 297            ⋯ 2016-03-01 14:16:00+08:00 11.10020 124.0299
# 411            ⋯ 2016-03-07 11:44:00+08:00 10.50377 124.0331
# ...

# %%
#Make dataset of only individuals with valid depths
at_depth<-metadat[!is.na(metadat$Depth_ft),]

# %%
#Make percents dataset showing percent of reads OF THOSE MAPPING TO SYMBIONT GENERA
percents<-symbionts_filt[,c(1,3:5)]
percents$max_frac<-apply(percents, MARGIN=1, FUN=max_frac)

# %%
#Calculate percent of symbiont reads that mapped to each taxon
percents$clad_per <- symbionts_filt$clad_reads/rowSums(symbionts_filt[,3:5])
percents$dur_per <- symbionts_filt$dur_reads/rowSums(symbionts_filt[,3:5])
percents$sym_per <- symbionts_filt$sym_reads/rowSums(symbionts_filt[,3:5])
percents$taxon <- symbionts_filt$taxa
colnames(percents)[1]<-'Sample_ID'

# %%
#Add depth and distance to shore data
symb_depth<-inner_join(at_depth,percents)
# Out:
# Joining with `by = join_by(Sample_ID)`

# %%
#Get depth of Durusdinium dominant individuals
symb_depth[symb_depth$ID %in% dur_dat$IND,'Depth_ft']
# Out:
# [1] 13

# %%
#ANOVA for read percentages by Acropora taxon
summary(aov(clad_per ~ taxon, data=symb_depth))
summary(aov(dur_per ~ taxon, data=symb_depth))
summary(aov(sym_per ~ taxon, data=symb_depth))
# Out:
#             Df Sum Sq  Mean Sq F value Pr(>F)
# taxon        1 0.0000 0.000031   0.005  0.945
# Residuals   95 0.6042 0.006360
#             Df  Sum Sq   Mean Sq F value Pr(>F)
# taxon        1 0.00044 0.0004422   0.146  0.704
# Residuals   95 0.28842 0.0030360
#             Df  Sum Sq  Mean Sq F value Pr(>F)
# taxon        1 0.00071 0.000706   0.222  0.639
# Residuals   95 0.30238 0.003183

# %%
#Look at correlation between % Symbiodinium reads and depth
summary(lm(sym_per ~ Depth_ft,data=symb_depth))
cor(symb_depth$sym_per,symb_depth$Depth_ft)
# Out:
# Call:
# lm(formula = sym_per ~ Depth_ft, data = symb_depth)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05716 -0.03084 -0.01636  0.01012  0.22359
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.154387   0.014234  10.846   <2e-16 ***
# Depth_ft    -0.000976   0.001042  -0.937    0.351
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05622 on 95 degrees of freedom
# Multiple R-squared:  0.009153,	Adjusted R-squared:  -0.001277
# F-statistic: 0.8776 on 1 and 95 DF,  p-value: 0.3512
# [1] -0.09567151

# %%
#Look at correlation between % Cladocopium reads and depth
summary(lm(clad_per ~ Depth_ft,data=symb_depth))
cor(symb_depth$clad_per,symb_depth$Depth_ft)
# Out:
# Call:
# lm(formula = clad_per ~ Depth_ft, data = symb_depth)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.44333 -0.01056  0.02052  0.04615  0.07790
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.762951   0.020091  37.974   <2e-16 ***
# Depth_ft    0.001430   0.001471   0.973    0.333
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07936 on 95 degrees of freedom
# Multiple R-squared:  0.009859,	Adjusted R-squared:  -0.0005637
# F-statistic: 0.9459 on 1 and 95 DF,  p-value: 0.3332
# [1] 0.09929186

# %%
#Look at correlation between % Durusdinium reads and depth
summary(lm(dur_per ~ Depth_ft,data=symb_depth))
cor(symb_depth$dur_per,symb_depth$Depth_ft)
# Out:
# Call:
# lm(formula = dur_per ~ Depth_ft, data = symb_depth)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03108 -0.01793 -0.01148  0.00197  0.50049
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0826616  0.0139458   5.927 4.93e-08 ***
# Depth_ft    -0.0004542  0.0010207  -0.445    0.657
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05508 on 95 degrees of freedom
# Multiple R-squared:  0.00208,	Adjusted R-squared:  -0.008424
# F-statistic: 0.198 on 1 and 95 DF,  p-value: 0.6573
# [1] -0.04560934

# %%
plot(symb_depth$Depth_ft,symb_depth$dur_per,main="%Durusdinium by depth",cex.lab=1.5,cex.axis=1.2,axes=TRUE,frame.plot=FALSE,xlab="Depth in ft",ylab="% Durusdinium",cex.main=1.4)
# Out:
# Plot with title “%Durusdinium by depth”

# %%
plot(symb_depth$Depth_ft,symb_depth$sym_per,main="%Symbiodinium by depth",cex.lab=1.5,cex.axis=1.2,axes=TRUE,frame.plot=FALSE,xlab="Depth in ft",ylab="% Symbiodinium",cex.main=1.4)
# Out:
# Plot with title “%Symbiodinium by depth”

# %%
plot(symb_depth$Depth_ft,symb_depth$clad_per,main="%Cladocopium by depth",cex.lab=1.5,cex.axis=1.2,axes=TRUE,frame.plot=FALSE,xlab="Depth in ft",ylab="% Cladocopium",cex.main=1.4)
# Out:
# Plot with title “%Cladocopium by depth”

# %%
#Can we predict sample depth from relative percentages of different symbiong genera? Absolutely not
summary(lm(Depth_ft ~ clad_per+ dur_per+ sym_per,data=symb_depth))
# Out:
# Call:
# lm(formula = Depth_ft ~ clad_per + dur_per + sym_per, data = symb_depth)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -8.770 -3.172 -0.644  2.113 29.269
#
# Coefficients: (1 not defined because of singularities)
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    4.884      8.698   0.562    0.576
# clad_per       9.289     10.056   0.924    0.358
# dur_per        4.907     14.545   0.337    0.737
# sym_per           NA         NA      NA       NA
#
# Residual standard error: 5.535 on 94 degrees of freedom
# Multiple R-squared:  0.01106,	Adjusted R-squared:  -0.009985
# F-statistic: 0.5255 on 2 and 94 DF,  p-value: 0.593

# %%
#Join with metadat for distance to shore analyses
symb_meta<-inner_join(metadat,percents)
# Out:
# Joining with `by = join_by(Sample_ID)`

# %%
plot(symb_meta$SHOREDIST,symb_meta$clad_per,main="%Cladocopium by distance to shore",xlim=c(0,1000))
# Out:
# Plot with title “%Cladocopium by distance to shore”

# %%
plot(symb_meta$SHOREDIST,symb_meta$dur_per,main="%Durusdinium by distance to shore",xlim=c(0,1000))
# Out:
# Plot with title “%Durusdinium by distance to shore”

# %%
plot(symb_meta$SHOREDIST,symb_meta$sym_per,main="%Symbiodinium by distance to shore",xlim=c(0,1000))
# Out:
# Plot with title “%Symbiodinium by distance to shore”

# %%
#Can we predict sample distance to shore from relative percentages of different symbiont genera? We cannot
summary(lm(SHOREDIST ~ clad_per+ sym_per + dur_per,data=symb_meta))
# Out:
# Call:
# lm(formula = SHOREDIST ~ clad_per + sym_per + dur_per, data = symb_meta)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -13953  -3324  -3089  -2612  47838
#
# Coefficients: (1 not defined because of singularities)
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    16188       7953   2.036   0.0427 *
# clad_per      -12304       8630  -1.426   0.1550
# sym_per       -23191      14041  -1.652   0.0997 .
# dur_per           NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 11960 on 280 degrees of freedom
# Multiple R-squared:  0.01119,	Adjusted R-squared:  0.004125
# F-statistic: 1.584 on 2 and 280 DF,  p-value: 0.207
